# %% [markdown]
# ## Libraries and Helper Functions

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import re
import string
import nltk
from gensim.models import Word2Vec
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

from sklearn.decomposition import NMF, LatentDirichletAllocation, TruncatedSVD

from umap import UMAP
from hdbscan import HDBSCAN
from bertopic import BERTopic
from bertopic.representation import KeyBERTInspired,MaximalMarginalRelevance
from bertopic.representation import OpenAI as OpenAI_BERTopic
from sentence_transformers import SentenceTransformer

from gensim.corpora import Dictionary
from gensim.models import CoherenceModel

import os
from dotenv import load_dotenv

import optuna

nltk.download('punkt')
nltk.download('stopwords')

import torch
import random
import os
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\hanif\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\hanif\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
load_dotenv(override=True)
# Out:
# True

# %%
import openai
from openai import OpenAI
import json

openai.api_key = os.getenv("OPENAI_API_KEY")
client = OpenAI()

def summarize_topic(keywords, docs):
    prompt = f"Saya mempunyai sebuah topik terkait literatur ilmiah terkait riset dan inovasi kecerdasan buatan yang dapat di-deskripsikan dengan beberapa kata kunci berikut: {keywords}\n\n"
    prompt += "Di dialam topik ini, dokumen-dokumen berikut yang merupakan abstrak dari literatur ilmiah merupakan sebagian kecil namun representatif dari semua dokumen dalam topik ini:\n\n"
    prompt += "\n\n".join(docs[:5])  # ambil 5 dokumen saja
    prompt += 'Berdasarkan informasi di atas, deskripsikan topik ini dan berikan label berupa satu kaliamat yang representatif terhadap topik ini dengan format JSON berikut:\n {"label_topik":<label> , "deskripsi":<deskripsi>}'
    response = client.chat.completions.create(
        model="gpt-4o-2024-08-06",
        messages=[
            {"role": "system", "content": 'Kamu adalah asisten akademik yang merangkum topik. Anda adalah model yang hanya menjawab dalam format JSON valid. Jangan beri penjelasan. Berikan hanya output seperti ini: {"label_topik": "...", "deskripsi": "..."}'},
            {"role": "user", "content": prompt}
        ],
        temperature=0.5,
        max_tokens=300
    )
    content = response.choices[0].message.content.strip()
    try:
        match = re.search(r'\{.*?\}', content, re.DOTALL)
        json_str = match.group(0)
        result = json.loads(json_str)
        return result
    except json.JSONDecodeError:
        print("JSON tidak valid")

# %%
def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    os.environ['PYTHONHASHSEED'] = str(seed)
    
set_seed()
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\hanif\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\hanif\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import time
class StopWatch():
    def __init__(self):
        self.__start_time = 0
        self.__end_time = 0
        self.__elapsed_time = 0
    def start(self):
        self.__start_time = time.time()
        self.__end_time = 0
    def stop(self):
        self.__end_time = time.time()
        self.__elapsed_time = self.__end_time - self.__start_time
    def print(self):
        detik = self.__elapsed_time

        jam = detik // 3600
        detik = detik % 3600

        menit = detik // 60
        detik = detik % 60

        print('Waktu eksekusi: ',end='')
        if jam != 0:
            print(int(jam),'jam ',end='')
        if menit != 0:
            print(int(menit),'menit',end='')
        print(f' {detik:.2f}','detik.')
    def get_elapsed_time(self):
        return self.__elapsed_time

# %%
repeated_phrases = ["artificial intelligence"]

additional_stop_words = ['ai']

stop_words = set(stopwords.words('english'))
for word in additional_stop_words:
    stop_words.add(word)

def preprocess_text(text):
    # Lowercasing
    text = text.lower()
    
    # URL removal
    text = re.sub(r'http\S+|www\S+|https\S+', '', text, flags=re.MULTILINE)
    
    # Punctuation removal
    text = text.translate(str.maketrans('', '', string.punctuation))

    # Remove repeated phrases
    for phrase in repeated_phrases:
        text = re.sub(phrase,"",text)

    # Remove duplicate white space
    text = re.sub(r'\s+', ' ', text)

     # Tokenization
    tokens = word_tokenize(text)
    
    # Stopword removal
    tokens = [word for word in tokens if word not in stop_words]
    
    return ' '.join(tokens)

# %%
def trim(x):
    if x[-7:]==' △ Less':
        return x[:-7]
    else:
        return x

# %%
def display_topics(model, feature_names, no_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print(f"\nTopic #{topic_idx + 1}:")
        print(" ".join([feature_names[i] for i in topic.argsort()[:-no_top_words - 1:-1]]))

# %%
def get_topics_words(model, vectorizer):
    feature_names = vectorizer.get_feature_names_out()
    topics_words = []
    for topic_idx, topic in enumerate(model.components_):
        top_features_ind = topic.argsort()[:-11:-1]
        top_words = [feature_names[i] for i in top_features_ind]
        topics_words.append(top_words)

    return topics_words

def get_bert_topics_words(topic_model):
    bert_topics_words = []
    for topic_id in topic_model.get_topics().keys():
        if topic_id == -1:
            continue
        topic_words = [word for word, _ in topic_model.get_topic(topic_id)]
        bert_topics_words.append(topic_words)
    return bert_topics_words

def get_coherence(topics_words):
    sw = StopWatch()
    sw.start()
    
    coherence = CoherenceModel(
                    topics=topics_words,
                    texts=tokenized_docs,
                    dictionary=dictionary,
                    coherence='c_v'
                ).get_coherence()

    sw.stop()
    sw.print()

    return coherence

# %%
config = {
    'dataset_dir' : '../../Datasets/'
}

# %% [markdown]
# ## EDA

# %%
df = pd.read_csv(config['dataset_dir']+'ai_articles.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16379 entries, 0 to 16378
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           16379 non-null  object
#  1   authors         16379 non-null  object
#  2   abstract        16379 non-null  object
#  3   submitted_date  16379 non-null  object
#  4   pdf_link        16379 non-null  object
# dtypes: object(5)
# memory usage: 639.9+ KB

# %%
df.head()
# Out:
#                                                title  \
# 0  Quantifying Natural and Artificial Intelligenc...
# 1  GraATP: A Graph Theoretic Approach for Automat...
# 2  Learning Word Representations from Relational ...
# 3  Genetic Algorithms in Wireless Networking: Tec...
# 4  ROSS User's Guide and Reference Manual (Versio...
#
#                                              authors  \
# 0                                       Hector Zenil
# 1  Mohammad Murtaza Mahmud;Swakkhar Shatabda;Moha...
# 2  Danushka Bollegala;Takanori Maehara;Yuichi Yos...
# 3  Usama Mehboob;Junaid Qadir;Salman Ali;Athanasi...
# 4                                   Glenn R. Hofford
#
#                                             abstract     submitted_date  \
# 0  One of the most important aims of the fields o...  23 December, 2014
# 1  Automated Theorem Proving (ATP) is an establis...  18 December, 2014
# 2  Attributes of words and relations between two ...   7 December, 2014
# 3  In recent times, wireless access technology is...  19 November, 2014
# 4  The ROSS method is a new approach in the area ...  15 November, 2014
#
#                           pdf_link
# 0  https://arxiv.org/pdf/1412.6703
# 1  https://arxiv.org/pdf/1412.5980
# 2  https://arxiv.org/pdf/1412.2378
# 3  https://arxiv.org/pdf/1411.5323
# 4  https://arxiv.org/pdf/1411.4194

# %%
df['submitted_date'] = pd.to_datetime(df['submitted_date'])
df['submitted_year'] = df['submitted_date'].dt.year
df['submitted_month'] = df['submitted_date'].dt.month

# %%
df = df[df['submitted_year'] >= 2020].reset_index()

# %%
df
# Out:
#        index                                              title  \
# 0       1716  LAIF: AI, Deep Learning for Germany Suetterlin...
# 1       1717  Neural Networks, Artificial Intelligence and t...
# 2       1718  The case for psychometric artificial general i...
# 3       1719  A survey of the European Union's artificial in...
# 4       1720  A Review of Artificial Intelligence Technologi...
# ...      ...                                                ...
# 14658  16374                    Towards Regulated Deep Learning
# 14659  16375  Learning from the Past: How Previous Technolog...
# 14660  16376  The Multi-Agent Reinforcement Learning in Malm...
# 14661  16377  Probability Bracket Notation: Markov Sequence ...
# 14662  16378  Probability Bracket Notation: Multivariable Sy...
#
#                                                  authors  \
# 0              Enkhtogtokh Togootogtokh;Christian Klasen
# 1                                    Martin C. Nwadiugwu
# 2                                         Mark McPherson
# 3                                         Charlotte Stix
# 4                              Kuo Yang;Emad A. Mohammed
# ...                                                  ...
# 14658                               Andrés García-Camino
# 14659        Risto Miikkulainen;Jerry Smith;Babak Hodjat
# 14660  Diego Perez-Liebana;Katja Hofmann;Sharada Pras...
# 14661                                       Xing M. Wang
# 14662                                       Xing M. Wang
#
#                                                 abstract submitted_date  \
# 0      One of the successful early implementation of ...     2020-12-30
# 1      In recent years, several studies have provided...     2020-12-25
# 2      A short review of the literature on measuremen...     2020-12-27
# 3      Compared to other global powers, the European ...     2020-12-28
# 4      Alzheimer's Disease (AD) is a severe brain dis...     2020-12-21
# ...                                                  ...            ...
# 14658  Regulation of Multi-Agent Systems (MAS) and De...     2025-07-18
# 14659  Artificial Intelligence (AI) is rapidly changi...     2025-05-25
# 14660  Learning in multi-agent scenarios is a fruitfu...     2025-04-11
# 14661  With the symbolic framework of Probability Bra...     2025-02-19
# 14662  The Probability Bracket Notation (PBN) is used...     2025-03-08
#
#                                pdf_link  submitted_year  submitted_month
# 0      https://arxiv.org/pdf/2101.10450            2020               12
# 1      https://arxiv.org/pdf/2101.08635            2020               12
# 2      https://arxiv.org/pdf/2101.02179            2020               12
# 3      https://arxiv.org/pdf/2101.02039            2020               12
# 4      https://arxiv.org/pdf/2101.01781            2020               12
# ...                                 ...             ...              ...
# 14658  https://arxiv.org/pdf/1912.13122            2025                7
# 14659  https://arxiv.org/pdf/1905.13178            2025                5
# 14660  https://arxiv.org/pdf/1901.08129            2025                4
# 14661   https://arxiv.org/pdf/1212.3817            2025                2
# 14662   https://arxiv.org/pdf/1207.5293            2025                3
#
# [14663 rows x 8 columns]

# %% [markdown]
# ## Preprocessing and Feature Engineering #1

# %%
df_tm = df.copy()
df_tm['text'] = df_tm['title']+" "+df_tm['abstract']
df_tm['text'] = df_tm['text'].apply(trim)

df_tm = df_tm[['text']]

# %%
df_tm
# Out:
#                                                     text
# 0      LAIF: AI, Deep Learning for Germany Suetterlin...
# 1      Neural Networks, Artificial Intelligence and t...
# 2      The case for psychometric artificial general i...
# 3      A survey of the European Union's artificial in...
# 4      A Review of Artificial Intelligence Technologi...
# ...                                                  ...
# 14658  Towards Regulated Deep Learning Regulation of ...
# 14659  Learning from the Past: How Previous Technolog...
# 14660  The Multi-Agent Reinforcement Learning in Malm...
# 14661  Probability Bracket Notation: Markov Sequence ...
# 14662  Probability Bracket Notation: Multivariable Sy...
#
# [14663 rows x 1 columns]

# %%
sw = StopWatch()
sw.start()
df_tm['processed_text'] = df_tm['text'].apply(preprocess_text)
sw.stop()
sw.print()
# Out:
# Waktu eksekusi:  11.87 detik.

# %%
df_tm.head()
# Out:
#                                                 text  \
# 0  LAIF: AI, Deep Learning for Germany Suetterlin...
# 1  Neural Networks, Artificial Intelligence and t...
# 2  The case for psychometric artificial general i...
# 3  A survey of the European Union's artificial in...
# 4  A Review of Artificial Intelligence Technologi...
#
#                                       processed_text
# 0  laif deep learning germany suetterlin letter r...
# 1  neural networks computational brain recent yea...
# 2  case psychometric artificial general intellige...
# 3  survey european unions ecosystem compared glob...
# 4  review technologies early prediction alzheimer...

# %% [markdown]
# ## Topic Modelling

# %%
docs = df_tm['processed_text'].to_list()

# %%
def get_top_keyword(vectorizer,model):
    componenets = model.components_
    feature_names = vectorizer.get_feature_names_out()
    top_n = 10
    keywords_per_topic = [
        [feature_names[i] for i in topic.argsort()[:-top_n - 1:-1]] for topic in componenets
    ]
    return keywords_per_topic

def select_representative_docs(model,topics):
    topics_docs = {}
    for topic_idx in range(model.n_components):
        topic_strength = topics[:,topic_idx]
        top_doc_indices = topic_strength.argsort()[::-1][:5]
        topics_docs[topic_idx] = [docs[i] for i in top_doc_indices]
    return topics_docs

# %%
def summarize(model, topics, vectorizer):
    r_docs = select_representative_docs(model,topics)
    top_key = get_top_keyword(vectorizer,model)
    topic_desc = {}
    for topic_idx, keywords in enumerate(top_key):
        docs_sample = r_docs[topic_idx]
        result = summarize_topic(keywords, docs_sample)
        topic_desc[topic_idx] = result
    return topic_desc

# %%
tfidf_vectorizer = TfidfVectorizer(max_features=1000)
tfidf = tfidf_vectorizer.fit_transform(df_tm['processed_text'])

count_vectorizer = CountVectorizer(max_features=1000)
count = count_vectorizer.fit_transform(df_tm['processed_text'])

# %% [markdown]
# ### NMF

# %%
sw = StopWatch()
sw.start()
nmf_model = NMF(n_components=90, random_state=42)
nmf_topics = nmf_model.fit_transform(tfidf)
sw.stop()
sw.print()

# %%
df_tm['NMF_topic'] = np.argmax(nmf_topics,axis=1)

# %%
df_tm['NMF_topic'].value_counts()

# %% [markdown]
# ### LDA

# %%
sw = StopWatch()
sw.start()
lda_model = LatentDirichletAllocation(n_components=90, random_state=42)
lda_topics = lda_model.fit_transform(count)
sw.stop()
sw.print()

# %%
df_tm['LDA_topic'] = np.argmax(lda_topics,axis=1)

# %%
df_tm['LDA_topic'].value_counts()

# %% [markdown]
# ### LSA

# %%
sw = StopWatch()
sw.start()
lsa_model = TruncatedSVD(n_components=90, random_state=42)
lsa_topics = lsa_model.fit_transform(tfidf)
sw.stop()
sw.print()

# %%
df_tm['LSA_topics'] = np.argmax(lsa_topics,axis=1)

# %%
df_tm['LSA_topics'].value_counts()

# %% [markdown]
# ### BERTopic

# %%
# Prepare sub-models
embedding_model = SentenceTransformer('sentence-transformers/all-mpnet-base-v2')
umap_model = UMAP(n_components=5, n_neighbors=50, random_state=42, metric="cosine", verbose=True)
hdbscan_model = HDBSCAN(min_samples=20, gen_min_span_tree=True, prediction_data=True, min_cluster_size=20)
vectorizer_model = CountVectorizer(ngram_range=(1, 3), min_df=5)

# %%
# # Prepare sub-models
# embedding_model = SentenceTransformer('sentence-transformers/all-mpnet-base-v2')
# umap_model = UMAP(n_components=5, n_neighbors=50, random_state=42, metric="cosine", verbose=True)
# hdbscan_model = HDBSCAN(min_samples=20, gen_min_span_tree=True, prediction_data=True, min_cluster_size=50)
# vectorizer_model = CountVectorizer(ngram_range=(1, 3), min_df=5)

# %%
# Representation models
representation_models = {
    "KeyBERTInspired": KeyBERTInspired()
}

# Fit BERTopic
sw = StopWatch()
sw.start()

topic_model= BERTopic(
        embedding_model=embedding_model,
        umap_model=umap_model,
        hdbscan_model=hdbscan_model,
        vectorizer_model=vectorizer_model,
        representation_model=representation_models,
        verbose=True
).fit(docs)

sw.stop()
sw.print()

# %%
topic_info = topic_model.get_topic_info()  
id_to_name = topic_info.set_index("Topic")["Name"].to_dict()

# %%
id_to_name

# %%
topic_model.get_topic_info()

# %%
sw = StopWatch()
sw.start()

bert_topics, probs = topic_model.transform(docs)

sw.stop()
sw.print()

# %%
df_tm['BERT_topic'] = bert_topics

# %% [markdown]
# ### Evaluating #1

# %%
# Tokenisasi dokumen
tokenized_docs = [doc.split() for doc in docs]

dictionary = Dictionary(tokenized_docs)
corpus = [dictionary.doc2bow(text) for text in tokenized_docs]

# %%
nmf_topics_words = get_topics_words(nmf_model,tfidf_vectorizer)
lda_topics_words = get_topics_words(lda_model,count_vectorizer)
lsa_topics_words = get_topics_words(lsa_model,tfidf_vectorizer)

# %%
bert_topics_words = get_bert_topics_words(topic_model)

# %%
get_coherence(bert_topics_words)

# %%
sw.start()

coherence_dict = {
    'Model' : [
        'NMF',
        'LDA',
        'LSA',
        'BERTopic',
    ],
    'Coherence':[
        get_coherence(nmf_topics_words),
        get_coherence(lda_topics_words),
        get_coherence(lsa_topics_words),
        get_coherence(bert_topics_words),
    ]
}

sw.stop()
sw.print()

# %%
coherence_df = pd.DataFrame(coherence_dict)

# %%
coherence_df

# %% [markdown]
# ### Hyperparameter Tuning

# %%
optuna.__version__

# %%
def nmf_objective(trial):
    params = {
        'n_components': trial.suggest_int('n_components', 3, 100)
    }

    model = NMF(**params, random_state=42)
    topics = model.fit_transform(tfidf)

    topics_words = get_topics_words(model, tfidf_vectorizer)
    return get_coherence(topics_words)

def lda_objective(trial):
    params = {
        'n_components': trial.suggest_int('n_components', 3, 100)
    }

    model = LatentDirichletAllocation(**params, random_state=42)
    topics = model.fit_transform(count)

    topics_words = get_topics_words(model, count_vectorizer)
    return get_coherence(topics_words)

def lsa_objective(trial):
    params = {
        'n_components': trial.suggest_int('n_components', 3, 100)
    }

    model = TruncatedSVD(**params, random_state=42)
    topics = model.fit_transform(tfidf)

    topics_words = get_topics_words(model, tfidf_vectorizer)
    return get_coherence(topics_words)

def bert_objective(trial):
    embedding_model = SentenceTransformer('sentence-transformers/all-mpnet-base-v2')
    umap_model = UMAP(n_components=5, n_neighbors=50, random_state=42, metric="cosine", verbose=True)
    hdbscan_model = HDBSCAN(min_samples=20, gen_min_span_tree=True, prediction_data=True, min_cluster_size=trial.suggest_int('min_cluster_size', 3, 30))
    vectorizer_model = CountVectorizer(ngram_range=(1, 3), min_df=5)

    representation_models = {
        "KeyBERTInspired": KeyBERTInspired()
    }

    topic_model= BERTopic(
            embedding_model=embedding_model,
            umap_model=umap_model,
            hdbscan_model=hdbscan_model,
            vectorizer_model=vectorizer_model,
            representation_model=representation_models,
            verbose=True
    ).fit(docs)

    bert_topics_words = get_bert_topics_words(topic_model)
    return get_coherence(bert_topics_words)

# %%
# sw.start()

# nmf_study = optuna.create_study(direction='maximize')
# nmf_study.optimize(nmf_objective,n_trials=20)

# sw.stop()
# sw.print()

# %%
nmf_parmas = {'n_components': 22}

# %%
# sw.start()

# lda_study = optuna.create_study(direction='maximize')
# lda_study.optimize(lda_objective,n_trials=20)

# sw.stop()
# sw.print()

# %%
lda_params = {'n_components': 44}

# %%
# sw.start()

# lsa_study = optuna.create_study(direction='maximize')
# lsa_study.optimize(lsa_objective,n_trials=20)

# sw.stop()
# sw.print()

# %%
lsa_params = {'n_components': 3}

# %%
# sw.start()

# bert_study = optuna.create_study(direction='maximize')
# bert_study.optimize(bert_objective,n_trials=5)

# sw.stop()
# sw.print()

# %%
bert_params = {'min_cluster_size': 22}

# %%
nmf_model = NMF(**nmf_parmas, random_state=42)
nmf_topics = nmf_model.fit_transform(tfidf)

lda_model = LatentDirichletAllocation(**lda_params, random_state=42)
lda_topics = lda_model.fit_transform(count)

lsa_model = TruncatedSVD(**lsa_params, random_state=42)
lsa_topics = lsa_model.fit_transform(tfidf)

# %%
len(docs)

# %%
client = os.getenv("OPENAI_API_KEY")

# %%
summarization_prompt = """
I have a topic that is described by the following keywords: [KEYWORDS]
In this topic, the following documents are a small but representative subset of all documents in the topic:
[DOCUMENTS]

Based on the information above, give a description of this topic in the following format:
topic: <description>
"""
summarization_model = OpenAI_BERTopic(model="gpt-3.5-turbo", chat=True, prompt=summarization_prompt, nr_docs=5, exponential_backoff=True, diversity=0.1,client=client)

# %%
# Prepare sub-models
embedding_model = SentenceTransformer('sentence-transformers/all-mpnet-base-v2')
umap_model = UMAP(n_components=5, n_neighbors=50, random_state=42, metric="cosine", verbose=True)
hdbscan_model = HDBSCAN(min_samples=20, gen_min_span_tree=True, prediction_data=True, min_cluster_size=50)
vectorizer_model = CountVectorizer(ngram_range=(1, 3), min_df=5)

# Representation models
representation_models = {
    "KeyBERTInspired": KeyBERTInspired()
}

# Fit BERTopic
sw = StopWatch()
sw.start()

topic_model= BERTopic(
        embedding_model=embedding_model,
        umap_model=umap_model,
        hdbscan_model=hdbscan_model,
        vectorizer_model=vectorizer_model,
        representation_model=representation_models,
        verbose=True
).fit(docs)

sw.stop()
sw.print()
# Out:
# 2025-07-26 19:56:31,937 - BERTopic - Embedding - Transforming documents to embeddings.
# Batches:   0%|          | 0/459 [00:00<?, ?it/s]
# 2025-07-26 20:04:28,440 - BERTopic - Embedding - Completed ✓
# 2025-07-26 20:04:28,441 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# UMAP(angular_rp_forest=True, metric='cosine', n_components=5, n_jobs=1, n_neighbors=50, random_state=42, verbose=True)
# Sat Jul 26 20:04:28 2025 Construct fuzzy simplicial set
# Sat Jul 26 20:04:28 2025 Finding Nearest Neighbors
# Sat Jul 26 20:04:28 2025 Building RP forest with 11 trees
# Sat Jul 26 20:04:38 2025 NN descent for 14 iterations
# 	 1  /  14
# 	 2  /  14
# 	 3  /  14
# 	Stopping threshold met -- exiting after 3 iterations
# Sat Jul 26 20:05:13 2025 Finished Nearest Neighbor Search
# Sat Jul 26 20:05:18 2025 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Sat Jul 26 20:05:31 2025 Finished embedding
# 2025-07-26 20:05:32,081 - BERTopic - Dimensionality - Completed ✓
# 2025-07-26 20:05:32,083 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2025-07-26 20:05:32,823 - BERTopic - Cluster - Completed ✓
# 2025-07-26 20:05:32,829 - BERTopic - Representation - Fine-tuning topics using representation models.
# 2025-07-26 20:05:52,118 - BERTopic - Representation - Completed ✓
# Waktu eksekusi: 9 menit 22.74 detik.

# %%
nmf_topics_words = get_topics_words(nmf_model,tfidf_vectorizer)
lda_topics_words = get_topics_words(lda_model,count_vectorizer)
lsa_topics_words = get_topics_words(lsa_model,tfidf_vectorizer)

# %%
bert_topics_words = get_bert_topics_words(topic_model)

# %%
sw.start()

coherence_dict = {
    'Model' : [
        'NMF',
        'LDA',
        'LSA',
        'BERTopic',
    ],
    'Coherence':[
        get_coherence(nmf_topics_words),
        get_coherence(lda_topics_words),
        get_coherence(lsa_topics_words),
        get_coherence(bert_topics_words),
    ]
}

sw.stop()
sw.print()

# %%
coherence_df = pd.DataFrame(coherence_dict)
coherence_df

# %% [markdown]
# ## Conclusion

# %%
from bertopic import BERTopic

# %%
topic_model.save("BERTopic_ENG")
# Out:
# 2025-07-26 20:07:54,721 - BERTopic - WARNING: When you use `pickle` to save/load a BERTopic model,please make sure that the environments in which you saveand load the model are **exactly** the same. The version of BERTopic,its dependencies, and python need to remain the same.

# %%
bert_model = BERTopic.load("BERTopic_ENG")
# Out:
# Sat Jul 26 20:08:59 2025 Building and compiling search function

# %%
topics = bert_model.transform(docs)
# Out:
# Batches:   0%|          | 0/459 [00:00<?, ?it/s]
# 2025-07-26 20:17:13,132 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-07-26 20:17:13,207 - BERTopic - Dimensionality - Completed ✓
# 2025-07-26 20:17:13,208 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-07-26 20:17:14,066 - BERTopic - Cluster - Completed ✓

# %%
df = df.drop(columns=['index'])
df['BERTopic'] = topics[0]

# %%
df = df[df['BERTopic'] != -1]

# %%
df.shape
# Out:
# (9353, 8)

# %%
bert_topic_info = bert_model.get_topic_info()

# %%
bert_topic_info = bert_topic_info.iloc[1:,:]

# %%
bert_topic_info
# Out:
#     Topic  Count                                               Name  \
# 1       0   1400                0_medical_clinical_images_diagnosis
# 2       1    785         1_xai_explanations_explainable_explanation
# 3       2    575                2_ethical_governance_ethics_systems
# 4       3    425              3_attacks_attack_adversarial_security
# 5       4    391             4_students_education_educational_genai
# 6       5    367          5_llms_language_reasoning_language models
# 7       6    326                     6_wireless_network_6g_networks
# 8       7    323               7_molecular_materials_drug_discovery
# 9       8    300                    8_neural_learning_deep_networks
# 10      9    269                      9_fairness_bias_biases_gender
# 11     10    268                 10_neural_brain_learning_continual
# 12     11    264             11_traffic_driving_autonomous_vehicles
# 13     12    240                       12_game_games_players_agents
# 14     13    239                  13_embodied_robot_robots_planning
# 15     14    227              14_creativity_creative_art_generative
# 16     15    190               15_multimodal_visual_mllms_reasoning
# 17     16    188                16_hardware_memory_accelerators_gpu
# 18     17    183  17_software_code_software engineering_engineering
# 19     18    181      18_spiking_neuromorphic_neural_spiking neural
# 20     19    178            19_intelligence_agi_consciousness_human
# 21     20    171        20_federated_fl_federated learning_learning
# 22     21    157   21_quantum_quantum computing_classical_computing
# 23     22    155  22_emotion_emotional_emotions_emotion recognition
# 24     23    137              23_agricultural_agriculture_crop_food
# 25     24    106         24_energy_environmental_carbon_sustainable
# 26     25     83                       25_news_political_fake_media
# 27     26     82                    26_data_ml_quality_data quality
# 28     27     75                     27_3d_generation_video_quality
# 29     28     73           28_weather_forecasting_climate_forecasts
# 30     29     72  29_semantic_communication_semantic communicati...
# 31     30     71         30_research_papers_scientific_publications
# 32     31     70               31_optical_computing_neural_networks
# 33     32     70                   32_trading_financial_stock_price
# 34     33     69            33_blockchain_iot_decentralized_privacy
# 35     34     68                        34_legal_law_court_judicial
# 36     35     63                         35_space_physics_data_mars
# 37     36     63                  36_music_musical_generation_audio
# 38     37     61             37_speech_asr_audio_speech recognition
# 39     38     60              38_privacy_unlearning_data_protection
# 40     39     58        39_chatbot_chatbots_conversational_language
# 41     40     58      40_federated_healthcare_federated learning_fl
# 42     41     57             41_edge_computing_cloud_edge computing
# 43     42     53                      42_retinal_dr_images_diabetic
# 44     43     52               43_deepfake_detection_forgery_images
# 45     44     50     44_knowledge_commonsense_graph_knowledge graph
#
#                                        Representation  \
# 1   [medical, clinical, images, diagnosis, cancer,...
# 2   [xai, explanations, explainable, explanation, ...
# 3   [ethical, governance, ethics, systems, moral, ...
# 4   [attacks, attack, adversarial, security, detec...
# 5   [students, education, educational, genai, lear...
# 6   [llms, language, reasoning, language models, l...
# 7   [wireless, network, 6g, networks, channel, com...
# 8   [molecular, materials, drug, discovery, protei...
# 9   [neural, learning, deep, networks, optimizatio...
# 10  [fairness, bias, biases, gender, fair, groups,...
# 11  [neural, brain, learning, continual, networks,...
# 12  [traffic, driving, autonomous, vehicles, safet...
# 13  [game, games, players, agents, player, learnin...
# 14  [embodied, robot, robots, planning, robotic, r...
# 15  [creativity, creative, art, generative, fashio...
# 16  [multimodal, visual, mllms, reasoning, models,...
# 17  [hardware, memory, accelerators, gpu, performa...
# 18  [software, code, software engineering, enginee...
# 19  [spiking, neuromorphic, neural, spiking neural...
# 20  [intelligence, agi, consciousness, human, arti...
# 21  [federated, fl, federated learning, learning, ...
# 22  [quantum, quantum computing, classical, comput...
# 23  [emotion, emotional, emotions, emotion recogni...
# 24  [agricultural, agriculture, crop, food, remote...
# 25  [energy, environmental, carbon, sustainable, g...
# 26  [news, political, fake, media, social, social ...
# 27  [data, ml, quality, data quality, machine lear...
# 28  [3d, generation, video, quality, quality asses...
# 29  [weather, forecasting, climate, forecasts, wea...
# 30  [semantic, communication, semantic communicati...
# 31  [research, papers, scientific, publications, p...
# 32  [optical, computing, neural, networks, neural ...
# 33  [trading, financial, stock, price, time series...
# 34  [blockchain, iot, decentralized, privacy, bloc...
# 35  [legal, law, court, judicial, language, reason...
# 36  [space, physics, data, mars, machine, detector...
# 37  [music, musical, generation, audio, sound, com...
# 38  [speech, asr, audio, speech recognition, recog...
# 39  [privacy, unlearning, data, protection, machin...
# 40  [chatbot, chatbots, conversational, language, ...
# 41  [federated, healthcare, federated learning, fl...
# 42  [edge, computing, cloud, edge computing, iot, ...
# 43  [retinal, dr, images, diabetic, diagnosis, ima...
# 44  [deepfake, detection, forgery, images, fake, i...
# 45  [knowledge, commonsense, graph, knowledge grap...
#
#                                       KeyBERTInspired  \
# 1   [medical imaging, medical image, deep learning...
# 2   [explainable xai, explainability, interpretabi...
# 3   [governance, ethics, ethical, accountability, ...
# 4   [adversarial attacks, adversarial, deep learni...
# 5   [learners, generative genai, pedagogical, educ...
# 6   [language models llms, language model, languag...
# 7   [6g networks, 6g wireless, 5g, wireless commun...
# 8   [drug discovery, deep learning, bioinformatics...
# 9   [neural network, neural networks, deep neural,...
# 10  [algorithmic fairness, fairness metrics, fairn...
# 11  [artificial neural, neural, neurons, neural ne...
# 12  [autonomous vehicles, autonomous driving, inte...
# 13  [reinforcement learning, game theory, multiage...
# 14  [robotics, robotic, robot, robotic systems, ro...
# 15  [human creativity, creativity, generative, art...
# 16  [multimodal models, visual question answering,...
# 17  [hardware accelerators, gpus, deep neural, dee...
# 18  [software engineering, software development, s...
# 19  [neuromorphic computing, spiking neural, spiki...
# 20  [artificial general intelligence, intelligence...
# 21  [federated learning, federated learning fl, di...
# 22  [quantum computing, quantum, quantum mechanics...
# 23  [emotion recognition, emotion, emotions, emoti...
# 24  [agriculture, agricultural, farmers, remote se...
# 25  [energy consumption, energy management, energy...
# 26  [disinformation, news articles, fake, social m...
# 27  [data quality, data management, big data, data...
# 28  [video generation, image generation, visual qu...
# 29  [weather forecasting, forecasting system, fore...
# 30  [semantic communications, semantic communicati...
# 31  [bibliometric, citations, publications, resear...
# 32  [optoelectronic, neural network, backpropagati...
# 33  [lstm, forecasting, timeseries, time series, s...
# 34  [blockchain technology, blockchain, smart cont...
# 35  [natural language processing, judiciary, judic...
# 36  [anomaly detection, deep learning, machine lea...
# 37  [music, genres, composition, musical, composit...
# 38  [speech recognition asr, speech recognition, a...
# 39  [data privacy, privacy preservation, privacy p...
# 40  [chatbots, chatbot, conversational agents, dia...
# 41  [federated learning, smart healthcare, federat...
# 42  [edge computing, edge networks, cloud edge, ed...
# 43  [retinal, deep learning, diabetic, diabetes, i...
# 44  [deepfake detection, deepfake, convolutional n...
# 45  [knowledge graph, commonsense knowledge, knowl...
#
#                                   Representative_Docs
# 1   [online learning xray ct mri medical imaging p...
# 2   [whats meant explainable model scoping review ...
# 3   [connecting dots trustworthy principles ethics...
# 4   [resisting deep learning models adversarial at...
# 5   [generative modern education society transitio...
# 6   [mathlearner large language model agent framew...
# 7   [overview communication 6g network fundamental...
# 8   [tokenmol 10 tokenized drug design large langu...
# 9   [partial differential equations need generatin...
# 10  [unfair norms fairness research metaanalysis a...
# 11  [neural networks computational brain recent ye...
# 12  [networklevel safety metrics overall traffic s...
# 13  [navigating landscape multiplayer games multip...
# 14  [survey languagebased communication robotics e...
# 15  [assessing understanding creativity large lang...
# 16  [exploring reasoning abilities multimodal larg...
# 17  [addernet minimalist hardware design energyeff...
# 18  [augmenting software engineering developing to...
# 19  [rectified linear postsynaptic potential funct...
# 20  [intelligence sequencing pathdependence intell...
# 21  [flex flexible federated learning framework re...
# 22  [qubitbased framework quantum machine learning...
# 23  [emoinhindi multilabel emotion intensity annot...
# 24  [semantic segmentation approach sweet orange l...
# 25  [ai4ef energy efficiency building sector ai4ef...
# 26  [towards smart fake news detection explainable...
# 27  [aidriven frameworks enhancing data quality bi...
# 28  [scene123 one prompt 3d scene generation via v...
# 29  [seeds emulation weather forecast ensembles di...
# 30  [semantic communications via features identifi...
# 31  [impact responsible research innovation develo...
# 32  [spatially varying nanophotonic neural network...
# 33  [parallelnetwork continuous quantitative tradi...
# 34  [applications blockchain improve performance i...
# 35  [exploring nexus large language models legal s...
# 36  [analyze mass spectrometry data assist underst...
# 37  [survey foundation models music understanding ...
# 38  [salmonn towards generic hearing abilities lar...
# 39  [machine learning meets privacy survey outlook...
# 40  [creation chatbot based natural language procc...
# 41  [privacy preserving federated learning medical...
# 42  [edge intelligence confluence edge computing a...
# 43  [automated retinal image analysis medical repo...
# 44  [towards openworld generalized deepfake detect...
# 45  [aser towards largescale commonsense knowledge...

# %%
bert_topic_info.columns
# Out:
# Index(['Topic', 'Count', 'Name', 'Representation', 'KeyBERTInspired',
#        'Representative_Docs'],
#       dtype='object')

# %%
# def summarize_bert(topics_info):
#     r_docs = topics_info['Representative_Docs'].to_list()
#     top_key = topics_info['KeyBERTInspired'].to_list()
#     topic_desc = {}
#     for topic_idx, keywords in enumerate(top_key):
#         docs_sample = r_docs[topic_idx]
#         result = summarize_topic(keywords, docs_sample)
#         topic_desc[topic_idx] = result
#     return topic_desc

# %%
# bert_sum = summarize_bert(bert_topic_info)

# %%
# with open("bert_sum.json", "w", encoding="utf-8") as f:
#     json.dump(bert_sum, f, ensure_ascii=False, indent=4)

# %%
with open("bert_sum.json", "r", encoding="utf-8") as f:
    bert_sum = json.load(f)

# %%
df
# Out:
#                                                    title  \
# 1      Neural Networks, Artificial Intelligence and t...
# 2      The case for psychometric artificial general i...
# 3      A survey of the European Union's artificial in...
# 5      Deep Unsupervised Identification of Selected S...
# 6      Limitations of Deep Neural Networks: a discuss...
# ...                                                  ...
# 14655  Artificial Intelligence Governance for Businesses
# 14656    FederBoost: Private Federated Learning for GBDT
# 14657  LIMEtree: Consistent and Faithful Surrogate Ex...
# 14659  Learning from the Past: How Previous Technolog...
# 14660  The Multi-Agent Reinforcement Learning in Malm...
#
#                                                  authors  \
# 1                                    Martin C. Nwadiugwu
# 2                                         Mark McPherson
# 3                                         Charlotte Stix
# 5                           Julia Siekiera;Stefan Kramer
# 6                                    Stefanos Tsimenidis
# ...                                                  ...
# 14655  Johannes Schneider;Rene Abraham;Christian Mesk...
# 14656  Zhihua Tian;Rui Zhang;Xiaoyang Hou;Lingjuan Ly...
# 14657                           Kacper Sokol;Peter Flach
# 14659        Risto Miikkulainen;Jerry Smith;Babak Hodjat
# 14660  Diego Perez-Liebana;Katja Hofmann;Sharada Pras...
#
#                                                 abstract submitted_date  \
# 1      In recent years, several studies have provided...     2020-12-25
# 2      A short review of the literature on measuremen...     2020-12-27
# 3      Compared to other global powers, the European ...     2020-12-28
# 5      The exploration of selected single nucleotide ...     2020-12-28
# 6      Deep neural networks have triggered a revoluti...     2020-12-22
# ...                                                  ...            ...
# 14655  Artificial Intelligence (AI) governance regula...     2025-07-16
# 14656  Federated Learning (FL) has been an emerging t...     2025-02-27
# 14657  Explainable artificial intelligence provides t...     2025-02-26
# 14659  Artificial Intelligence (AI) is rapidly changi...     2025-05-25
# 14660  Learning in multi-agent scenarios is a fruitfu...     2025-04-11
#
#                                pdf_link  submitted_year  submitted_month  \
# 1      https://arxiv.org/pdf/2101.08635            2020               12
# 2      https://arxiv.org/pdf/2101.02179            2020               12
# 3      https://arxiv.org/pdf/2101.02039            2020               12
# 5      https://arxiv.org/pdf/2101.00004            2020               12
# 6      https://arxiv.org/pdf/2012.15754            2020               12
# ...                                 ...             ...              ...
# 14655  https://arxiv.org/pdf/2011.10672            2025                7
# 14656  https://arxiv.org/pdf/2011.02796            2025                2
# 14657  https://arxiv.org/pdf/2005.01427            2025                2
# 14659  https://arxiv.org/pdf/1905.13178            2025                5
# 14660  https://arxiv.org/pdf/1901.08129            2025                4
#
#        BERTopic
# 1            10
# 2            19
# 3             2
# 5             7
# 6             8
# ...         ...
# 14655         2
# 14656        20
# 14657         1
# 14659         2
# 14660        12
#
# [9353 rows x 8 columns]

# %%
df['topic_label'] = df['BERTopic'].apply(lambda x: bert_sum[str(x)]['label_topik'])

# %%
df
# Out:
#                                                    title  \
# 1      Neural Networks, Artificial Intelligence and t...
# 2      The case for psychometric artificial general i...
# 3      A survey of the European Union's artificial in...
# 5      Deep Unsupervised Identification of Selected S...
# 6      Limitations of Deep Neural Networks: a discuss...
# ...                                                  ...
# 14655  Artificial Intelligence Governance for Businesses
# 14656    FederBoost: Private Federated Learning for GBDT
# 14657  LIMEtree: Consistent and Faithful Surrogate Ex...
# 14659  Learning from the Past: How Previous Technolog...
# 14660  The Multi-Agent Reinforcement Learning in Malm...
#
#                                                  authors  \
# 1                                    Martin C. Nwadiugwu
# 2                                         Mark McPherson
# 3                                         Charlotte Stix
# 5                           Julia Siekiera;Stefan Kramer
# 6                                    Stefanos Tsimenidis
# ...                                                  ...
# 14655  Johannes Schneider;Rene Abraham;Christian Mesk...
# 14656  Zhihua Tian;Rui Zhang;Xiaoyang Hou;Lingjuan Ly...
# 14657                           Kacper Sokol;Peter Flach
# 14659        Risto Miikkulainen;Jerry Smith;Babak Hodjat
# 14660  Diego Perez-Liebana;Katja Hofmann;Sharada Pras...
#
#                                                 abstract submitted_date  \
# 1      In recent years, several studies have provided...     2020-12-25
# 2      A short review of the literature on measuremen...     2020-12-27
# 3      Compared to other global powers, the European ...     2020-12-28
# 5      The exploration of selected single nucleotide ...     2020-12-28
# 6      Deep neural networks have triggered a revoluti...     2020-12-22
# ...                                                  ...            ...
# 14655  Artificial Intelligence (AI) governance regula...     2025-07-16
# 14656  Federated Learning (FL) has been an emerging t...     2025-02-27
# 14657  Explainable artificial intelligence provides t...     2025-02-26
# 14659  Artificial Intelligence (AI) is rapidly changi...     2025-05-25
# 14660  Learning in multi-agent scenarios is a fruitfu...     2025-04-11
#
#                                pdf_link  submitted_year  submitted_month  \
# 1      https://arxiv.org/pdf/2101.08635            2020               12
# 2      https://arxiv.org/pdf/2101.02179            2020               12
# 3      https://arxiv.org/pdf/2101.02039            2020               12
# 5      https://arxiv.org/pdf/2101.00004            2020               12
# 6      https://arxiv.org/pdf/2012.15754            2020               12
# ...                                 ...             ...              ...
# 14655  https://arxiv.org/pdf/2011.10672            2025                7
# 14656  https://arxiv.org/pdf/2011.02796            2025                2
# 14657  https://arxiv.org/pdf/2005.01427            2025                2
# 14659  https://arxiv.org/pdf/1905.13178            2025                5
# 14660  https://arxiv.org/pdf/1901.08129            2025                4
#
#        BERTopic                                        topic_label
# 1            10  Riset dan Inovasi dalam Kecerdasan Buatan Berb...
# 2            19  Evolusi dan Tantangan Artificial General Intel...
# 3             2                Governance and Ethics in AI Systems
# 5             7  Innovative Deep Learning Approaches in Drug Di...
# 6             8  Riset dan Inovasi dalam Kecerdasan Buatan deng...
# ...         ...                                                ...
# 14655         2                Governance and Ethics in AI Systems
# 14656        20  Federated Learning and Data Privacy in Distrib...
# 14657         1           Explainable AI (XAI) in Machine Learning
# 14659         2                Governance and Ethics in AI Systems
# 14660        12  Inovasi dan Strategi Kecerdasan Buatan dalam P...
#
# [9353 rows x 9 columns]

# %%
def plot_topik_by_tahun(df, tahun):
    """
    Membuat barplot distribusi label_topik untuk tahun tertentu.

    Parameter:
    - df: DataFrame yang berisi kolom 'label_topik' dan 'pubdate'
    - tahun: Tahun (integer) yang ingin divisualisasikan
    """
    # Filter berdasarkan tahun
    df_filtered = df[df['submitted_year'] == tahun]

    if df_filtered.empty:
        print(f"Tidak ada data untuk tahun {tahun}")
        return

    # Hitung frekuensi topik
    topic_counts = df_filtered['topic_label'].value_counts()

    # Plot barplot
    plt.figure(figsize=(12, 6))
    sns.barplot(
        x=topic_counts.values,
        y=topic_counts.index,
        palette="viridis"
    )
    plt.xlabel("Jumlah")
    plt.ylabel("Topik")
    plt.title(f"Distribusi Topik Literatur Ilmiah Berbahasa Indonesia pada Tahun {tahun}")

    # Ambil 5 topik teratas untuk legend
    top_5_labels = topic_counts.head(5).index.tolist()

    # # Tambahkan legend manual
    # from matplotlib.patches import Patch
    # legend_handles = [Patch(color=sns.color_palette("viridis")[i], label=label)
    #                   for i, label in enumerate(top_5_labels)]
    # plt.legend(handles=legend_handles, title="5 Topik Teratas", loc="upper right")

    plt.tick_params(axis='y', labelsize=9)  # Atur ukuran label y-axis
    plt.tight_layout()
    plt.savefig(f"Distribusi Topik Literatur Ilmiah Berbahasa Inggris pada Tahun {tahun}.png",dpi=300, bbox_inches="tight")
    plt.show()

# %%
plot_topik_by_tahun(df,2020)

# %%
plot_topik_by_tahun(df,2021)

# %%
plot_topik_by_tahun(df,2022)

# %%
plot_topik_by_tahun(df,2023)

# %%
plot_topik_by_tahun(df,2024)

# %%
plot_topik_by_tahun(df,2025)

# %%
bert_df = pd.DataFrame()
bert_df['topic_id'] = bert_topic_info['Topic']
bert_df['keyword'] = bert_topic_info['KeyBERTInspired']
bert_df['topic_label'] = bert_df['topic_id'].apply(lambda x : bert_sum[str(x)]['label_topik'])
bert_df['topic_desc'] = bert_df['topic_id'].apply(lambda x : bert_sum[str(x)]['deskripsi'])

# %%
bert_df.to_csv('Topik Artikel Bahasa Inggris.csv',index=False)

# %%
df.to_csv('ENG_articles_labeled.csv',index=False)
